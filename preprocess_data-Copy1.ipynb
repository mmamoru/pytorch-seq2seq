# %%
import re
import emoji
import pickle
import os
group_len=3

# %%
def delete_self_reply_pairs(twitter_data):
    dialogue_tweets = []
    for i in range(1,len(twitter_data),3):
        if re.match('@',twitter_data[i])!=None:
            dialogue_tweets.append(twitter_data[i-1])
            dialogue_tweets.append(twitter_data[i])
            dialogue_tweets.append(twitter_data[i+1])
    return dialogue_tweets

# %%
def delete_hashtag_tweets_groups(twitter_data):
    hashtag = r'[#＃]([\w一-龠ぁ-んァ-ヴーａ-ｚ]+( |　))'
    dialogue_tweets = []
    for i in range(0,len(twitter_data),3):
        if re.search(hashtag,twitter_data[i])==None and re.search(hashtag,twitter_data[i+1])==None and re.search(hashtag,twitter_data[i+2])==None:
            dialogue_tweets.append(twitter_data[i])
            dialogue_tweets.append(twitter_data[i+1])
            dialogue_tweets.append(twitter_data[i+2])
        else:
            pass
    return dialogue_tweets

# %%
def delete_hashtag_eos(twitter_data):
    hashtag = r'[#＃]([\w一-龠ぁ-んァ-ヴーａ-ｚ]+$)'
    dialogue_tweets = []
    for ele in twitter_data:
        ele_hashtag_deleted = re.sub(hashtag,'',ele)
        dialogue_tweets.append(ele_hashtag_deleted)
    return dialogue_tweets

# %%
def delete_url(twitter_data):
    url = r'(https?|ftp)(:\/\/[-_\.!~*\'()a-zA-Z0-9;\/?:\@&=\+\$,%#]+)'
    dialogue_tweets = []
    for ele in twitter_data:
        ele_url_deleted = re.sub(url,'',ele)
        dialogue_tweets.append(ele_url_deleted)
    return dialogue_tweets

# %%
def delete_username_sos(twitter_data):
    username = r'@([a-zA-Z0-9_…]+ )'
    dialogue_tweets = []
    for ele in twitter_data:
        ele_username_deleted = re.sub(username,'',ele)
        dialogue_tweets.append(ele_username_deleted)
    return dialogue_tweets

# %%
def delete_inline_username(twitter_data):
    username = r'@([a-zA-Z0-9_…]+)'
    dialogue_tweets = []
    for ele in twitter_data:
        ele_username_deleted = re.sub(username,'',ele)
        dialogue_tweets.append(ele_username_deleted)
    return dialogue_tweets

# %%
def delete_emoji(twitter_data):
    dialogue_tweets = []
    for ele in twitter_data:
        ele_emoji_deleted = ''.join(char for char in ele if char not in emoji.UNICODE_EMOJI)
        dialogue_tweets.append(ele_emoji_deleted)
    return dialogue_tweets

# %%
def delete_brackets(twitter_data):
    brackets = []
    brackets.append(r'【(.+)】')
    brackets.append(r'《(.+)》')
    brackets.append(r'\((.+)\)')
    brackets.append(r'（(.+)）')
    dialogue_tweets = []
    for ele in twitter_data:
        for bracket in brackets:
            ele = re.sub(bracket,'',ele)
        dialogue_tweets.append(ele)
    return dialogue_tweets

# %%
def delete_blank(twitter_data):
    space = r'\s+'
    dialogue_tweets = []
    for i in range(0,len(twitter_data),3):
        if twitter_data[i]=='' or twitter_data[i+1]=='' or twitter_data[i+2]=='':
            pass
        elif re.match(space,twitter_data[i])!=None or re.match(space,twitter_data[i+1])!=None or re.match(space,twitter_data[i+2])!=None:
            pass
        else:
            dialogue_tweets.append(twitter_data[i])
            dialogue_tweets.append(twitter_data[i+1])
            dialogue_tweets.append(twitter_data[i+2])
    return dialogue_tweets

# %%
def delete_line_feed_code(twitter_data):
    dialogue_tweets = []
    for ele in twitter_data:
        ele_code_deleted = re.sub('\n','',ele)
        dialogue_tweets.append(ele_code_deleted)
    return dialogue_tweets

# %%
def delete_same_char_sequence(twitter_data):
    dialogue_tweets = []
    for ele in twitter_data:
        deleted_ele = re.sub(r'あ{2,}','あ',ele)
        deleted_ele = re.sub(r'い{3,}','い',deleted_ele)
        deleted_ele = re.sub(r'う{2,}','う',deleted_ele)
        deleted_ele = re.sub(r'え{3,}','え',deleted_ele)
        deleted_ele = re.sub(r'お{2,}','お',deleted_ele)
        deleted_ele = re.sub(r'ア{2,}','あ',deleted_ele)
        deleted_ele = re.sub(r'イ{3,}','い',deleted_ele)
        deleted_ele = re.sub(r'ウ{2,}','う',deleted_ele)
        deleted_ele = re.sub(r'エ{3,}','え',deleted_ele)
        deleted_ele = re.sub(r'オ{2,}','お',deleted_ele)
        deleted_ele = re.sub(r'ぁ{2,}','ぁ',deleted_ele)
        deleted_ele = re.sub(r'ぃ{2,}','ぃ',deleted_ele)
        deleted_ele = re.sub(r'ぅ{2,}','ぅ',deleted_ele)
        deleted_ele = re.sub(r'ぇ{2,}','ぇ',deleted_ele)
        deleted_ele = re.sub(r'ぉ{2,}','ぉ',deleted_ele)
        deleted_ele = re.sub(r'ァ{2,}','ぁ',deleted_ele)
        deleted_ele = re.sub(r'ィ{2,}','ぃ',deleted_ele)
        deleted_ele = re.sub(r'ゥ{2,}','ぅ',deleted_ele)
        deleted_ele = re.sub(r'ェ{2,}','ぇ',deleted_ele)
        deleted_ele = re.sub(r'ォ{2,}','ぉ',deleted_ele)
        deleted_ele = re.sub(r'w{2,}','w',deleted_ele.lower())
        deleted_ele = re.sub(r'ｗ{2,}','w',deleted_ele)
        deleted_ele = re.sub(r'[…\,\.]','',deleted_ele)
        deleted_ele = re.sub(r'!{2,}','!',deleted_ele)
        deleted_ele = re.sub(r'！{2,}','!',deleted_ele)
        deleted_ele = re.sub(r'笑{2,}','笑',deleted_ele)
        dialogue_tweets.append(deleted_ele)
    return dialogue_tweets

# %%
import neologdn

def neolog_normalize(twitter_data):
    dialogue_tweets = []
    for ele in twitter_data:
        normalized_ele = neologdn.normalize(ele)
        dialogue_tweets.append(normalized_ele)
    return dialogue_tweets

# %%
def pre_process(twitter_data,save=False,save_name='twitter_preprocessed.pickle'):    
    try:
        twitter_data_ = delete_self_reply_pairs(twitter_data)
        twitter_data_ = delete_hashtag_tweets_groups(twitter_data_)
        twitter_data_ = delete_hashtag_eos(twitter_data_)
        twitter_data_ = delete_url(twitter_data_)
        twitter_data_ = delete_username_sos(twitter_data_)
        twitter_data_ = delete_inline_username(twitter_data_)
        twitter_data_ = delete_brackets(twitter_data_)
        twitter_data_ = delete_emoji(twitter_data_)
        twitter_data_ = delete_blank(twitter_data_)
        data = delete_line_feed_code(twitter_data_)
        num_rawdata = int(len(twitter_data)/3)
        num_processed_data = int(len(data)/3)
    data.close()
print(len(twitter_data))
# Out:
# 14876862

# %%
print(len(twitter_data))
processed_data = pre_process(twitter_data,save=False,save_name='twitter_preprocessed1121.pickle')
print(len(processed_data))
# Out:
# 14876862
# The Number of Raw Data: 4958954
# The Number of Pre-processed Data: 4079971
# Yield Rate: 0.8227483053885961
# 12239913

# %%
def delete_blank(twitter_data):
    space = r'\s+'
    dialogue_tweets = []
    garbege = []
    for i in range(0,len(twitter_data),3):
        if twitter_data[i]=='' or twitter_data[i+1]=='' or twitter_data[i+2]=='':
            garbege.append(twitter_data[i])
            garbege.append(twitter_data[i+1])
            garbege.append(twitter_data[i+2])
        elif re.match(space,twitter_data[i])!=None or re.match(space,twitter_data[i+1])!=None or re.match(space,twitter_data[i+2])!=None:
            garbege.append(twitter_data[i])
            garbege.append(twitter_data[i+1])
            garbege.append(twitter_data[i+2])
        else:
            dialogue_tweets.append(twitter_data[i])
            dialogue_tweets.append(twitter_data[i+1])
            dialogue_tweets.append(twitter_data[i+2])
    return dialogue_tweets,garbege

# %%
def pre_process(twitter_data,save=False,save_name='twitter_preprocessed.pickle'):    
    try:
        twitter_data_ = delete_self_reply_pairs(twitter_data)
        print(len(twitter_data_))
        twitter_data_ = delete_hashtag_tweets_groups(twitter_data_)
        print(len(twitter_data_))
        twitter_data_ = delete_hashtag_eos(twitter_data_)
        print(len(twitter_data_))
        twitter_data_ = delete_url(twitter_data_)
        print(len(twitter_data_))
        twitter_data_ = delete_username_sos(twitter_data_)
        print(len(twitter_data_))
        twitter_data_ = delete_inline_username(twitter_data_)
        print(len(twitter_data_))
        twitter_data_ = delete_brackets(twitter_data_)
        print(len(twitter_data_))
        twitter_data_ = delete_emoji(twitter_data_)
        print(len(twitter_data_))
        twitter_data_,garbege = delete_blank(twitter_data_)
        print(len(twitter_data_))
        data = delete_line_feed_code(twitter_data_)
        num_rawdata = int(len(twitter_data)/3)
        num_processed_data = int(len(data)/3)
        yield_rate = num_processed_data/num_rawdata
        print('The Number of Raw Data: '+str(num_rawdata))
        print('The Number of Pre-processed Data: '+str(num_processed_data))
        print('Yield Rate: '+str(yield_rate))
        if(save):
            save_file = open(save_name,'wb') 
            pickle.dump(data,save_file)
            save_file.close
        return data,garbege
    except:
        import traceback
        print('pre-processing is failed')
        traceback.print_exc()
        return None
    
print(len(twitter_data))
processed_data,garbege1 = pre_process(twitter_data,save=False,save_name='twitter_preprocessed1121.pickle')
print(len(processed_data))
print(len(garbege1))
# Out:
# 14876862
# 13355601
# 12887226
# 12887226
# 12887226
# 12887226
# 12887226
# 12887226
# 12887226
# 12239913
# The Number of Raw Data: 4958954
# The Number of Pre-processed Data: 4079971
# Yield Rate: 0.8227483053885961
# 12239913
# 647313

# %%
def pre_process1(twitter_data,save=False,save_name='twitter_preprocessed.pickle'):    
    try:
        twitter_data_ = delete_self_reply_pairs(twitter_data)
        print(len(twitter_data_))
        twitter_data_ = delete_hashtag_tweets_groups(twitter_data_)
        print(len(twitter_data_))
        twitter_data_ = delete_hashtag_eos(twitter_data_)
        print(len(twitter_data_))
        twitter_data_ = delete_url(twitter_data_)
        print(len(twitter_data_))
        twitter_data_ = delete_username_sos(twitter_data_)
        print(len(twitter_data_))
        twitter_data_ = delete_inline_username(twitter_data_)
        print(len(twitter_data_))
        twitter_data_ = delete_brackets(twitter_data_)
        print(len(twitter_data_))
        twitter_data_ = delete_emoji(twitter_data_)
        print(len(twitter_data_))
        twitter_data_ = delete_same_char_sequence(twitter_data_)
        print(len(twitter_data_))
        twitter_data_ = neolog_normalize(twitter_data_)
        print(len(twitter_data_))
        twitter_data_,garbege = delete_blank(twitter_data_)
        print(len(twitter_data_))
        data = delete_line_feed_code(twitter_data_)
        num_rawdata = int(len(twitter_data)/3)
        num_processed_data = int(len(data)/3)
        yield_rate = num_processed_data/num_rawdata
        print('The Number of Raw Data: '+str(num_rawdata))
        print('The Number of Pre-processed Data: '+str(num_processed_data))
        print('Yield Rate: '+str(yield_rate))
        if(save):
            save_file = open(save_name,'wb') 
            pickle.dump(data,save_file)
            save_file.close
        return data,garbege
    except:
        import traceback
        print('pre-processing is failed')
        traceback.print_exc()
        return None
print(len(twitter_data))
processed_data,garbege = pre_process1(twitter_data,save=False,save_name='twitter_preprocessed1121.pickle')
print(len(processed_data))
print(len(garbege))
# Out:
# 14876862
# 13355601
# 12887226
# 12887226
# 12887226
# 12887226
# 12887226
# 12887226
# 12887226
# 12887226
# 12887226
# 12442335
# The Number of Raw Data: 4958954
# The Number of Pre-processed Data: 4147445
# Yield Rate: 0.8363548038558132
# 12442335
# 444891

# %%
garbege2 = neolog_normalize(delete_same_char_sequence(garbege1[0:100]))
for i in range(100):
    print('sos'+garbege[i][:-1]+'eos    '+'sos'+garbege1[i][:-1]+'eos   '+'sos'+garbege2[i][:-1]+'eos\n')
    if i%3==2:
        print()
# Out:
# sosそう、猫の成長とてもはやいeos    sosそう、猫の成長とてもはやいeos   sosそう、猫の成長とてもはやいeos
#
# sos。ﾟﾟ。今も可愛いけどなeos    sos｡ﾟﾟ｡今も可愛いけどなeos   sos。ﾟﾟ。今も可愛いけどなeos
#
# soseos    soseos   soseos
#
#
# soseos    sos 動けや、笑eos   sos動けや、笑eos
#
# soseos    sos真顔を使うなし、これ使えᕕᕗ 動けない系女子だものeos   sos真顔を使うなし、これ使えᕕᕗ動けない系女子だものeos
#
# sos私サバ側3つしか出来てへんからなweos    sosどうやったらでてくるんwww でぶるeos   sosどうやったらでてくるんwでぶるeos
#
#
# soseos    sos '` eos   sos'` eos
#
# sosヤクザなウルトラ警備隊️eos    sos前言撤回️️️️eos   sos前言撤回️️️️eos
#
# sos暑くて熱中症手前水浴びeos    sosなんでよ！めっちゃ美味そうやん 私目玉焼き初めてつくった eos   sosなんでよ!めっちゃ美味そうやん私目玉焼き初めてつくったeos
#
#
# soseos    soseos   soseos
#
# sos名前weos    soseos   soseos
#
# sos狙ってるだろこんなんweos    sos私サバ側3つしか出来てへんからなwwweos   sos私サバ側3つしか出来てへんからなweos
#
#
# soseos    soseos   soseos
# 12239913

# %%
end = 51
i=18
#print(twitter_data[i:i+3])
print(len(twitter_data))
twitter_data_ = twitter_data#twitter_data[i:i+3]
twitter_data_ = delete_self_reply_pairs(twitter_data_)
twitter_data_ = delete_hashtag_tweets_groups(twitter_data_)
twitter_data_ = delete_hashtag_eos(twitter_data_)
twitter_data_ = delete_url(twitter_data_)
twitter_data_ = delete_username_sos(twitter_data_)
twitter_data_ = delete_inline_username(twitter_data_)
twitter_data_ = delete_brackets(twitter_data_)
twitter_data_ = delete_emoji(twitter_data_)
twitter_data_ = delete_same_char_sequence(twitter_data_)
twitter_data_ = neolog_normalize(twitter_data_)
twitter_data_ = delete_blank(twitter_data_)
data = delete_line_feed_code(twitter_data_)

print(len(data))
# print(len(data))
# print()
# print(twitter_data[0:end])
# Out:
# 14876862
# 12452004

# %%
a = ['大きなのっぽの古時計
     おじいさんの時計
     100年いつも動いていた']
delete_line_feed_code(a)
# Out:
# ['ほぼ答え',
#  '@雪見大福www',
#  'ほぼ答えだよねwww',
#  'おやすみなさいらいとさんきょうもすきです',
#  '@つけてやろうかおい',
#  '@つけると意外と反応するんだよらいとさん、困るわ',
#  '推し変ちゃうわピキピキ',
#  '@小池美波ちゃんくろとさんは推し変です。',
#  '@小池美波ちゃんワイはみいちゃん一筋やで',
#  'ようやくリアルの忙しさが終わりそう。でもモンストやる気出ない。',
#  '@こらそん@こらそん@こらそん@こらそん@こらそん@こらそん@こらそん@こらそん@こらそん@こらそん@こらそん@こらそん@こらそん@こらそん@こらそん@こらそん',
#  'メンションやばっwww一応生きてるので安心してくださいwww',
#  'おいおいおいほんと楽しいね毎日絡んでくれてありがとうクシクシこれからもよろしくンゴねえ',
#  '@打ったら3番目に出てきた!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!メイト行きたいからお金ください界隈変わっても好きだよお',
#  'おいおまえそこのおまえ、おい、最近絡んでなくね?オイオイ勘弁してくれってばよ...絡もうずぇ',
#  'ねぇ、思ったこと1つ聞いていい? suzuhaさんの「@」の後ろって本名?',
#  '@のうしろってhazukiって書いてあるとこやんな?違うよー!suzuhaが本名hazukiはネット用に作った名前w',
#  'なーんだ!そっか!w本名なら、私と同じ!って言おうとしたのにーwww',
#  'やられたww',
#  '@!!!',
#  'またやられたw',
#  '@あめさん切嗣めちゃくちゃ似てる……地声とのギャップしゅごい……!是非親子コラボしたいでしゅ……くるみの芽を探しましょ',
#  '@かっしーちゃんいつも枠来てくれてありがとなの!まだまだ知らない事多いからこれからもお話して仲良くなりたいのじゃ',
#  '@パパ盛お仕事おつかれなんやで!いつも美味しいお菓子ありがとだぞぉ……あと姐さんに送ってたラーメンわたしも今度食べてみたいなぁ',
#  '@パパ盛お仕事おつかれなんやで!いつも美味しいお菓子ありがとだぞぉ……あと姐さんに送ってたラーメンわたしも今度食べてみたいなぁ',
#  '@えみや',
#  '@うさやつしゃんめちゃくちゃ話しやすくてついつい夜更かししちゃうわ',
#  '.万6649人以下の有志の両親へ。杉田議員がもし謝罪外見したらそれだけで解決できるのか?引用説明してほしいlgbt、子供が親に説明してほしい。子供が親を訴え…',
#  '@ 2万6649人以下の両親←',
#  '引用。2万6649人以下の両親。',
#  'ほんまけ!wやっばその頃がなつい!w',
#  '@ ck_vipこんな感じの時に戻してみて下さいよ爆笑',
#  'なんでなんで!www',
#  'ごめんよももありがとう',
#  '@ baellet51',
#  'これやな可愛い',
#  'ちゃんと@もつけとくからwww馨が彼氏ね!黒ちゃん彼女ね!!私が黒ちゃん愛でる係だから!!',
#  '@つける意味w …って思ったら私もつけてたわ!wあり、逆じゃないのかwじゃあ私が愛でられる係かな?w',
#  'お前もか!!wwwまぁレスには付くもんだぞ!wえ、逆が良いの?wwwめちゃくちゃ愛で回したいのだ!',
#  '@ vipandabotさん♡',
#  '@ rain__readさん♡',
#  '@ bts_tata_suga_lちゃあん♡♡',
#  'なるほどなぁ。、にしてもこっちは弱気なガッツなのねw',
#  '@のあとよく見てください',
#  '強すぎwww盲点だったわw',
#  '何気ない推されが僕の心を傷つけた',
#  '@しおりの太もも界隈ぜったいかずちゃを殺そうな!',
#  'その発言凍結されるから消しとけwww',
#  '推し名と推しマーク皆さんのアイデアを募集しておりますどうぞリプライdmくだしあ',
#  '@淫乱',
#  'やめてwwwマークもとか出てたけども!!',
#  '@ _ 24俺の方が',
#  '@ _ 25沢山…',
#  '@ _ 26若気たよㅋ',
#  'i already wasted 2000 crystals, no luck...',
#  "@; i'll be joining you in that much pretty soon i'm sure once another 300 stack from rewards, etc. why m…",
#  'well, i hope you have more luck than me. keep the faith, remember "世界の果てまでbelieve heart"',
#  'これは本物のたかさんなのでしょうか…!ゴクリ…',
#  '@のところが違うので別人かと…',
#  'たかさん視聴者の方!!この方、本物ですか?',
#  '推しのidと推しらしい推しマ教えてや',
#  '@ risru17ぺちゃもおしえて!',
#  '@ m1tsu_32_お願いしまー!!',
#  'ありがとうございます。僕は親日のアーティストには応援を惜しみません。彼らが真摯に原爆被害者に謝罪するならファンになったのに残念です。',
#  '@*********btsってユダヤ人極右団体に英文でメール送っておいた。bts終わっ…',
#  'アメリカのユダヤ人団体が高須克弥院長を会員から除名したことを賞賛する声明を発表した。高須氏がtwitterにナチス・ドイツの指導者アドルフ・ヒトラーを称賛したり、ユダヤ人大量…',
#  'マジですか?w気づきませんでした',
#  '@のうしろが、torihikigr8estってなってますww',
#  'まじかwwwガッツリ取引する気満々ですねw',
#  'もしかしてhがダメ??',
#  '@では',
#  'にゃずあんジーニアスw',
#  'おやすみなさい、clickshit_2514さん',
#  '@がない-1145148101919点ぐっすり眠らせていただきナス!',
#  '@つけるとメンションになっちゃうんだよなぁ…まぁそれはともかくおやすみ!',
#  '。',
#  '@ぬーんがきになって仕方がないでございます',
#  '下の方に集中シテネ',
#  'るーふぁたちがよく話てる河田って人どんな人なのか少し気になるわw',
#  '@ 10320314gabuこの人やで!wキャスで口滑らせて本名自分で晒したアホ今ではカズユキさんみたいに本名ネタでいじられてる((',
#  'そりゃまぁご愁傷様やなwwwお互い本名晒した者どうし仲良くできそうやわw',
#  '@/506hariboやっとべっちゃんんんんんん',
#  '@/honeydrop_506べっちゃんスローガン',
#  '@/prismatic_jpジェヒョンうちわ',
#  '╭╮',
#  '@の最後のえきめもが気になるカナー',
#  '駅メモていうアプリや',
#  'メイド喫茶かポムの樹でしかオムライス食べない、、',
#  '@ほぉむのオムライスすき',
#  'e-maidのオムライスがすき',
#  'まあぶっちゃけ警察に見つからなきゃ補導されないけどこの時間高校生って補導対象では',
#  '@半年だわーてか私もあと半年で18とかびっくりだわー高校生に見えないのって辛いよまじめに()なんかこのまま身長とかも伸びなそうでしばらく中学生で余裕説浮上してるもの',
#  'もうすぐだねえ!身長は女子だしもう止まる歳でしょうなあ…まぁ若く見られるのは多分そのうち得するステータスになるよ',
#  'そろそろ脱godⅲしたいかなʬʬʬ',
#  '@獄卒が懐かしすぎる笑んで約1年と2ヵ月god ⅲはやばいっす笑',
#  '2700過ぎてからなかなかうまp上がらんのよねー੭ʬʬʬ',
#  'くさい一言くださいってどゆことですか?笑「君の見た目も好きだけど君の中身が1番好きなんだ。たまに口が悪くなったりぶりっ子したりするけどホントは誰よりも繊細な心を持ってて何事にも一生懸命なそんな君が大好きだよ依織。」こんな感じで…',
#  '@西谷依織さん',
#  'おいwwwお前がこれやったんか笑',
#  '@ love_1ramuさん8,10ですね',
#  '@ puatamanthaさん8、10あまり絡んだことないですね…もっとお話されてもよろしいんですのy(殴',
#  '@ tao__pioさん8と10かな',
#  'もしかして、@ほぉむカフェ?',
#  '@ほーむです\u200d️\u200d️',
#  'あ、やっぱりw知り合いが、そこのプラチナまで通いつめたって言ってたから名前だけは知ってました',
#  'いやだって暗すぎだし',
#  '@',
#  'イミワカンネ',
#  'まって何ポイント塗ってんの?',
#  '@このくらい',
#  '嘘でしょ…',
#  'ズンドコさんと呼べばいいのかな…',
#  '@のあとのやつ読まないと誰かわからなくなっててワロタズンドコさんだれおま',
#  'www私も診断メーカーに名付けてもらったからねw',
#  '@ aira_nnk503愛桜さん→愛ちゃん',
#  '@ mi_ya_se_宮瀬さん→宮ちゃん',
#  '@ raimu_0627凪さん→凪ちゃん',
#  '@ふーこもるさんとこの!!! bioの',
#  '@ぶなしめじぶなちゃ!!すとめも5もるとワンもお世話になりました₍ᐢ. ̫.ᐢ₎プリクラ撮ったりお話するのめた楽しかったよまたライブ被ったら会いたい!!!大好きな同担様',
#  '@こはるjelさん大好きなの伝わってくる!!!推し様と幸せになって欲しい所存でございますあんまり喋ったことないかな?絡みたい!',
#  '@りんりんりんりん大好きもうほんと大好き以上!',
#  '@はちまあなたは素晴らしい画力をもっていらっしゃるすこ。ほんとすこ。なんなんだ',
#  '@りづたむ毎回りづたぬって打ち間違えるもう名前りづたぬにしよ??',
#  '@マンシャの森の住人であるキリッきっとめっちゃ強い!!!!!砂漠で1度も会ったことないけどなんだか親近感がある♪猫様がおられるからであろうか…是非いつか狩りに連れてってもらって寄生したいwww',
#  '@なんでも助けてくれる!!!!!頼りになるぜ⸝ピョンピョンまおの中の砂漠での最後の砦とおもってる←',
#  '@とっても絵とssが上手⋆⸜居ると必ず背後に回りたくなる!!!!!絡みに行きたい人♡なんでこんなに惹かれるのか…これは恋!?←うぇーいwww',
#  '@とっても絵とssが上手⋆⸜居ると必ず背後に回りたくなる!!!!!絡みに行きたい人♡なんでこんなに惹かれるのか…これは恋!?←うぇーいwww',
#  '@いつも一緒に遊んでくれる♪♪困ったら助けてくれる変態仮面|´-`)チラッこれでssとりたいなーって言うといつも付き合ってくれて感謝!!!!!これからも変態仮面でいてください⋆⸜⸝ピョンピョン',
#  '@とっても仲良しなdk仲間⋆⸜ノ今遠くに行っているしいつも忙しそうである!!しかし一緒にレベリングとか金策とか行…',
#  '@./総ては貴方併せ。弩助平耽美、長文思考。紡ぐ言葉に耽美、弩助平の差異あれど貴方前では万年発情期の雑魚雌仕様。繋ぐ縁は壱参程度。砂糖たっぷりの苺対応。醜い嫉妬も束縛も縁を繋い…',
#  '@./ "百合"という名でデリへル嬢として生計を立てている女。自らでは現在の職業は天職だと思っている模様。赤い爪に艶のある黒髪、豊満な胸。自分の身体への自身は尽きない。首絞め、強姦、種付プレス等とい…',
#  '@./弩助平時あへおほ、諸語、♡使用。貴方との関係性は恋人、客、強姦魔等ご自由に。何れは施錠予定。死垢にて呟き有。細くも途切れる事の無い永き縁を望む。',
#  '日本のアミにお願いです。今日本でのbtsのツイタに有りもない事を書き込み、btsのイメージを傷つけようとする動きがあります。見つけた時には報告等をお願いします️事実でない事が広まらないように力を貸して下さい️日本語の…',
#  '@ taro91217966は偽物の映像もつけて本当のごとのように広めてます。',
#  '…にも沢山の事実でない書き込みがあります。',
#  'ちょっこっちが変な声出たわwww',
#  '@をつけないのが気遣いwww',
#  'ビックリして彼も変な声出すわwww',
#  'せっかくなんで名前募集しますpocky@の後に何かつけてください。',
#  '@リア充撲滅委員会会長になりたかった男ボッキーさんと98人がいいねしました',
#  '長いわwwwもう決まってるわwww',
#  '誰がなんて言おうとガゴメ昆布一択≦фωф≧疲れとか知らない≦фωф≧はぁ。≦фωф≧ヴァっ@@',
#  '@@こいつだれ。wwwwww',
#  'かわいくして',
#  '@ ; o3',
#  '@ ; o4',
#  '@ ; o5まあ待ッてなッて',
#  'ポッキーの日にチョコバット食べまくった同士いない??いるよね?✧',
#  '@がポッキーになってて可愛いwww',
#  'あと4分でさよならだけどね',
#  '呼ばれないって?',
#  '@のやつ!',
#  '単純に忘れてたわwww',
#  '@ kc_hibiki0616けーしーひびきぜろろくいちろくお嫁さんの名前はいってるなぁw',
#  '@ me_2018407みーにせんじゅうはちよんぜろなな407が気になる',
#  '@ rei_rei_77れいれいななななわかりやすいですね',
#  '@あんだーぼーほんあんだーぷくぷく',
#  '@だいきのありんこ415',
#  '@やまだの有岡87',
#  '@じゃんぷくるのるん',
#  '@いのおのりなの0907',
#  '@いのおのかみやまのうるじむ',
#  '@ゆりすけ0524',
#  '@ちぇんのちねじい',
#  '@めーぷるのあり415',
#  '@あんだーおーる5あーる',
#  '@だああいきの0507',
#  '@あのりおのかあのののの',
#  '@ゆーや0313',
#  '@ hey! say! jumpのりょうすけやまだ129',
#  '@みみみのににみ',
#  '@やまのぽてあんだー',
#  '@とぅるのるるるる1115',
#  '@まいのぷりんすのゆうり',
#  '@おじょう0723',
#  '@じゃにーず0924 0413',
#  '@すみれの0119',
#  '@ hey! say! jumpのちねんの113o',
#  '@あんだーぴーちのわいあんだー',
#  '@やまのおれ7',
#  '@あのね、好きが、好きすぎて、ダメ←語彙力いつか併せしよう⸝ピョンピョンもっと絡みに来てあなたと話してる時が一番楽しい←',
#  '@餌不足してない?体調大丈夫?ヤギ…',
#  '@ねぇ、ヤギ…会えてない率高くて餌不足してないか心配ただね、会った時餌わしずかみ辞めろwww取り…',
#  '@',
#  '@',
#  'を買ったらその後dkが来た件…',
#  'こいつぁ困った…',
#  '@つけてごろごろしてみたけど行っているかい?',
#  'きたには来たけど、なんでかなおシャンの前が4日まえのみっくんに',
#  '月曜日ジョイポリスからの少年たちしてきて楽しすぎて幸せすぎて脳内パラダイスしてたら@優馬に金曜日だー!',
#  '@優馬が面白すぎて声出して笑った',
#  '鮮やかな季節は@優馬に過ぎてくとことんgot it!www',
#  '@りおちゃあまねさん可愛い',
#  '@まちめろあまつきさんタピオカ可愛い',
#  '@かよちゃひさつかなさん可愛い雰囲気おとな',
#  '@まちめろあまつきさんタピオカ可愛い',
#  '@かよちゃひさつかなさん可愛い雰囲気おとな',
#  '@ちゃりもるでおだいすきスペオキ安定結婚しよ関東はよこい',
#  '僕を置いてあっけなく死んでしまうであろう君。そんな君に永遠に、いや、せめて僕が朽ちてしまうまで共に居て欲しいという叶わぬ夢を見る僕はきっと愚か者なのだろうね。まったく馬鹿みたいだ。それでも、僕はそれを願わずにはいられない…',
#  '@@',
#  'すまないが今は少しばかり取り込んでいてね…これでも読みながら待っていてくれないか。僕とより雅な会話を楽しむためのちょっとした注意書きだよ。',
#  '@.01ああ、君はどんな人なのかな',
#  '@.02君と早く言葉を交わしたい',
#  '@.03貴方は私を喜ばせるのが上手ね',
#  '@そら絵が上手い可愛い絡みたい',
#  '@山田そらる可愛い安定スペオキあいたい',
#  '@せりゆた灯油さん可愛い天使勝手に安定だと思ってる絵が上手いあいたい',
#  '本日の「東山奈央のラジオ@リビング」に、深川芹亜ちゃんがゲストに来てくれます明後日がお誕生日の芹亜を、みんなでぜひぜひお祝いしましょう♪実は一昨日も現場で会えたり、他の機会にもばったり会えた…',
#  '@リビングの収録とアフレコ現場で奈央が1年ぶりに芹亜と楽しかったことをたくさんやりましたが、やっぱり何よりも一番良かったことはですね…奈央はいつもみたいに芹亜と面白い話をたくさん話したり、芹亜と美…',
#  '今までの奈央と芹亜の姉姐関係みたいに奈央が芹亜と思い出に残る時間を過ごすことができたことは何よりも嬉しかったことです僕も芹亜と一緒にいる時の奈央の幸せそうな笑顔や楽しそうな声をたくさん聞いて、奈…',
#  'さんナメクジ!',
#  '@オカピの人ますやんか',
#  'さんゴーヤ!',
#  'お前目からあやしいひかりだしてるぞ',
#  '@ウルガモスを取りに来たであろうお前悪いことはいわない。フレンドサファリにいくらでもいるからそっち捕まえろ',
#  'トゥヒヒwwwサーセンwww',
#  '宮城青森まで現場ないのでみんなと仲良くしたいです',
#  '@瀬良ちゃんえ、現場被ってる??会えてないよね??全私が泣いてる早く会いたいんだ瀬良ちゃん次現場どこいるのー??',
#  '多分被ってると思うんだけど会えてないよね',
#  'やり直しました!',
#  '@を付けてお願いします、、w\u200d️',
#  'たびたびすみません!',
#  '@セレンりおくんのをたく♡えるぴょんの枠で見かけたの思い出した!貴重な同担だし仲良くなりたい!₍ᐢ. ̫.ᐢ₎',
#  '@れたりむるすのをたく♡',
#  'ありがと!たそちゃん',
#  '同じ苦しみを共有して',
#  '@って打って上に出てきた3人に送りつけるみたいなハッシュタグみたいな感じで共有して',
#  '非常にまずい',
#  '@みかけちゃん確認しました',
#  '@みかけちゃん今回のもオシャレな雰囲気が漂っていて素敵です。前から気になっていたのですが、なんていうアプリを使用して作っているのですか?もしよろしければ教えてください。',
#  'このアプリです。',
#  '@ともかちゃん遊ぶ',
#  '@りす濃くなりたい人ランキング1位の人',
#  '@こたつーわつーわ',
#  '@あじ浮上もっとしろや!!!',
#  '@ももかたんかなり繋がってから長い人!!!!',
#  '@ミオビフォーアフターすごい人₍ᐢ. ̫.ᐢ₎',
#  '仲間内でテーブルゲーム熱が加速していてつい、衝動的に買ってしまった。どれもデザインかわいいし「argoat」なんかエメラルドが素敵で使いたくなってくる。',
#  '@と#の記載を間違えてしまった。まぁええか',
#  'このエメラルドトークンだけで幸せになれそう。',
#  '@るこ推し様に沸いてるとこかわいいし顔面もかわいい人₍ᐢ. ̫.ᐢ₎',
#  '@ひなせちんこ',
#  '@かのんちゃん最近浮上してるかききたくなるくらいtlで見かけない人',
#  '@つきみちゃんゆくくんの歌の成長を一緒に見てる人!!',
#  '@むむ初絡み濃すぎたのに最近絡まなすぎておこている人',
#  '@なつさく再びつーわしたいと思ってる人',
#  '別垢で裏垢始めようかな...',
#  '@まってますww',
#  '需要ないよwww',
#  '@♡♡かプで迷った最近はあまり絡めてないね会場でお会いできたらええなとか思ってます️',
#  '@ペうぃ名古屋個握行くみたいやね!僕も行く予定やったんやけどその予定1日で崩壊したよん1人チョーカー楽しんで',
#  '@ yaってやったら青くなるんでスペース入れましたお話が上手い人だなってずっと思ってます!実はいつくるかなってcasも楽しみにしてるんですよ️そしてシンプルに会ってみたいです!!',
#  '@空き缶',
#  '@有休はない',
#  'ゼロというより、マイナス?',
#  '今日の@リビングも僕にとって思い出深い神回だから、今でも奈央がたくさんの人に大事に大事に言った言葉の本当の意味を深く考え続けています@リビングのスタジオで奈央の側にいるたびに、奈央はたくさんの…',
#  '@リビングのスタジオで奈央の側にいるたびに、奈央はたくさんの人から温かい言葉で深く考えることができたので、@リビングという家にいるときみたいに場所で、奈央にリラックスな気持ちをたくさんた伝え続ける…',
#  'だから奈央先日もたくさんの人の言葉の本当の意味を深く考えながらいつもみたいに奈央らしく楽しく@リビングを大事に収録さてくれて心の底から本当にありがとうね奈央は僕の人生の全てだから、これから先も…',
#  'やっぱりさぁ……まつはらぷろの結婚喜ぶべきなのは分かってるんだけど……正直寂しいよね……結婚してほしくなかったわ……',
#  '@正直な思いを述べてしまうオタクff外から失礼します。ファンは彼の幸せを祝うべきではありませんか?彼も一人の人間なんです。',
#  '@ ff外から失礼してくるオタク私は個人としての感想を述べたまでです。もちろん彼には幸せになって欲しいと思っていますが、寂しいと思うことも私の自由ではないでしょうか。',
#  '懐かしすぎて心痛めた',
#  '@ジャニくん',
#  'www画像めっちゃ持ってますね自分なさすぎてとりあえず頭に引っかかったやつググって見つけたの貼ったらなんか違ぇ️ってなりましたその画像のメモ帳タンスの中に1億個眠ってますわ!!!今年の秋はどこ行…',
#  '@くせらー',
#  '@かるていよりっと',
#  '@ゆで枝豆〈塩味〉88円+税',
#  '@かるていよりっと',
#  '@ゆで枝豆〈塩味〉88円+税',
#  '@うさまるさん',
#  '金馬獎の関係ですねドキュメンタリー映画の監督が台湾は独立国家と発言&gt;weiboで炎上&gt;台湾人はtwitterで飯テロ反撃ということですね',
#  '@共青团中央の掛け声で一斉に「中国一点都不能少」を唱え出す…ドイツのナチスのような全体主義を連想させて怖いです',
#  'ユーモアですね',
#  'はかせさんだ!ちょっと息できない!!!はかせさんに!ニックネーム?!!はかせんウオオオオアアアア\\/アアアアアッッッッ!!!!!',
#  '@そるとんたんそる!てんし!てんしそる!てんそる!?君は今から!てんそるだ!',
#  '一応それっぽいのフォトジェニコックハイスペック園長生イテテテテほぐほぐ天使…',
#  '一瞬戸惑ったわw',
#  '@なになに以外一緒だからなー',
#  '@なになに以外違うんだよ!',
#  'それな。',
#  '@スナ使いってなんか俺の名前と似てるな',
#  'アスナのスナだけやんけwww',
#  '咄嗟にユーザ名?@のやつ変えたわwww',
#  '@のとこ変えたらこっちの勝ちだよwww',
#  'よっしゃなめんなwww',
#  '突然のまめ指定',
#  '@打ったら上の方に出てきたからなんとなく指名したww',
#  'まぁやらんがな',
#  '心機一転といいますかなんといいますかユーザー名変えたいなって思うんですけど何かいい案ありませんか',
#  '@ circling_link',
#  '飛行機ですかね…!?!',
#  '@_73',
#  '@_74',
#  '@_74とりあえず散れ',
#  'こんばんは!お迎えありがとうございます!誤反応ではありませんのでぜひ繋がらせて頂きたいです!',
#  '@ xx_fso123こちらまでフォロリクお願い致します',
#  '@ 1から始まるアカウントからフォロリクを送らせて頂きましたのでお手隙の際にご確認いただけますと幸いです♡よろしくお願い致します!',
#  '@ 3人募集中ヾノ',
#  '@ 2募集中',
#  '@ 1募集中',
#  '三角関係大好物です!!!!あっでも両片思いのお相手様って私繋がってる方かしら……もし違かったら申し訳ない親子さんの確認だけしてから話し合いたいです...',
#  '@ rinoa_starnight親御さんこの方ですー!!もうすでに確認済みで、むしろドロドロな展開好きな方なので大丈夫ですよー!!!!やりましょ恋仲ところでお相手はどんな子で??',
#  '仕事が早いですね!?うちの子漁って出てきたのがこの子なんですけどキャラシも何も決まってなくて……ただからかったり焦らしたりするのが好きな子ですキャラシは早くて再来週あたりになると思…',
#  '@/ 23',
#  '@/ 24待っててね、勝手に消えないでね。',
#  '@/ 25待ってた。ずっと待ってた。',
#  '今から対べれ即席@ 5募集',
#  '@ 1です',
#  'とりあえずいいねもらった人へ',
#  'だれか詐欺ったの?(情報難民',
#  '@ teokun1116724この人が拡散してる人かナ()',
#  'うわぁ…有名さんなのにやらかしたねwww',
#  '本当にsr活動してたら全く絡みない方からフォロー勝手に来るんですよね自分がその人のルームに回収してたとしても、フォロー時に何も声掛けてくれないと発展すらしない笑笑',
#  '@で話し掛けてくれていいんだよ?って感じですよね',
#  'めっちゃ分かりますwフォローされてプロフィールは一応見るのですが、自分の中でピンと来なかったら放置笑笑たまに人じゃないアカウントからもフォロー来るけどどっから辿って来てるんだろwww',
#  '@ yuzu_bsd 3……ね……多分',
#  '@ vzigixuygwvrggaこら57番',
#  '5と7⁇',
#  '家帰ったら鍵しめられてた挙句チェーンまでかかってて家出禁かとおもっちゃった',
#  '@わたしあしたも1限から授業があります頑張ってください',
#  'オホホホホホホwww',
#  'しょーるーむの先輩からアドバイスいただきました!しょーるーむのふぁんみぃとのみなさん、お名前に自分の名前@肉片ちゃんバーチャル枠てきなかんじで、応援してる子のおなまえをいれるといいみたいです!お星様あつめとか、他のルームの方も来やすくなるようです!',
#  '@肉片ちゃんバーチャル応援とか、がいいかも?',
#  'こんな、感じ……?',
#  '8割坊主ってなにwwww角刈りかスポーツ刈りやろwwww',
#  '@更生つけるなら超短髪だぞ',
#  '@更生',
#  'あれ?前にもあったような…',
#  '@ホー…ゴホンゴホン',
#  '前のクランの名前完全に忘れてたわwww',
#  'というわけでサーモン@ 3募集ー',
#  '@ 2どなたかー',
#  '@ 1ですー!',
#  '結婚式の二次会で偶然出会ってロマンスをスタートさせたい',
#  '@梅澤美波様結局、誰推しなのでしょうか?',
#  'イェァ',
#  'なんかace内でブロックが流行ってるらしいので、ブロックして欲しい人いたらブロックするので言って下さい',
#  '@ aceかかってこいよ',
#  '欲しがりだなぁ',
#  '2123時リグマ募集めちゃくちゃ久々なんでゆるくできる方',
#  '@ 2わたしゆるちゃん',
#  '@ 1いぶきさん',
#  '黒澤と絡んでねーしwww',
#  '@',
#  'そういえばなんか当たったwww',
#  '@平川門',
#  '@大手門',
#  '@三井住友銀行',
#  "@ '' 미",
#  '@ 1大好きな貴方へ有難う',
#  '@ 2大切な貴方へ',
#  'とりあえず、テテだけ現地販売まとめてみましたまた見つかり次第ツイートします!他メンバーもツイートしていきます!アップ画像欲しい方言ってください\u200d️\u200d️4枚目',
#  '@/realv1230サンプル',
#  'お知らせこちらのタオル、東京リリイベでのみ販売されるそうです',
#  'タグ付けしてます?#じゃないやつ。',
#  '@はつけてないですね()',
#  'ここに未夢ちゃん名前検索してタグ付けするんです',
#  'ウァァァバケモンンン!!!!',
#  '@@@@チカラガホシイカ',
#  'ちょっとオシャレしてんじゃねえ!',
#  'またいつでもカラオケとか飲みいこ',
#  '@かやもとたいせいお前せめて第三者の顔は隠せ',
#  '隠した',
#  'お返事ありがとうございますフォローお願いします!!即フォロバします️',
#  '@ _tjから始まる垢からフォローさせていただきましたよろしくお願いします',
#  '@ _tjから始まる垢が見つからないんですけど@ jeからですかね?違ったらごめんなさい',
#  'シャリオス17世さんお久しぶりです東京も揺れました。寝てて起きたら揺れてました。プリンも揺れてます。ポムポムプリンカフェのクリスマス…',
#  '@ゆう師匠にシャリオス17世と名前を呼ばれるのは不思議な気分です…♪地震はこの後が心配ですね…プリン…',
#  'gif付け忘れてた汗',
#  '10/27',
#  '@2!!',
#  'しめ!',
#  '久々に対バン入ったけど、ヲタクの老化がすごいのかわからんが盛り上がりが足らない',
#  '@ jamか',
#  'そうだね。今フィーバーしてる。あかん。この子。',
#  'ってか、気づいんたんだけど、これ10人じゃないよねwwwwww',
#  '@で出てきた人全員入れた(',
#  'さすがや。わて、ばんたん出てきちゃったよwww',
#  '@ _ 74 sex',
#  '@ _ 75見逃したかも…',
#  '@ _ 76ぎゅっ',
#  '@ _ 76ぎゅっ',
#  '@ _ 77好き',
#  '@ _ 78これか?',
#  'フォロワー2万人のやつどれ!!',
#  '@ aaaliura',
#  'ありがとうございます!',
#  'えーわーいしましょ!!推しさんのidくれると!',
#  '@ ruki25_ruki!!!てにゃんは?',
#  'ありがと! @ _sile61!!!!',
#  'kポップセブチどっぷりぬまですなかよくしてください',
#  '@ツイートありがとうございます️ぜひ仲良くしましょさっそくですけど、ためでも大丈夫ですかね?',
#  'おへんじ、フォロバthank youですっタメウェルカム',
#  'だれだれ!!!',
#  '@ ylzoogtawtedgp1ていう子wwwww',
#  'いやユーザ名どうにかしてwww',
#  "@'1此処では紡ぐ言葉がどうしても長くなってしまうので、ぜひ部屋にでも",
#  "@'2今夜攫いに行く予定です。心の準備を",
#  "@'3きっと僕も貴方に会いたい、はず",
#  '推しさんのid教えて',
#  '@ kinako_fffデス!やみちのも教えて',
#  '@ juuuuukun0201です₍ᐢ. ̫.ᐢ₎',
#  '荷物捨ててスニーカーに履き変えれば解決',
#  '@川沿い川にぶん投げるか',
#  'こんな感じで',
#  'うむ!wwwかっこいいってよりかは、可愛いが@ってるかもw',
#  '@←これは、いったいなんだ!ww可愛いのか、、、俺のどこがwww',
#  '誤字!!!!wwwwww仕草が可愛いんだよ!!www',
#  '町田だああああああああああああああああああああああああああああああああああああああ',
#  '@町田',
#  'またニアミスwww',
#  '@赤坂てゃクラスの中で1番かっこいい赤坂てゃクラスの女子に拝められる。隣のクラスのさくやとは親友らしい',
#  '@臨音ちゃん活発な女の子でよくそらるを無理矢理にでも外に出させている。',
#  '@ゆいちゃとりあえず天使。授業中に推しとlineしていても怒られない()男子にとってはかわいい癒しと思っているがほんとは性癖やばい',
#  '往路の横手→湯沢で旧型客車+c61 20を従えて力走したde10 1759!旧型客車6両を連ねる姿は圧巻でした!中間にスハフ42の車掌室が来る組成も個人的には萌ポイント',
#  '@横手駅c61 20は復路でも給水・整備を行う為、一旦編成を離れています。',
#  '窓から大きく身を乗り出して車外に向かって刃物を振りかざす名物?のなまはげ氏。「オーイ!なまはげが来たぞー!良い写真撮れよ!」本人曰く約550年生きてるそうで、時々「疲れた…」と仰ってました',
#  '@ _ 09ごめんね。',
#  '@ _ 10遊びに来てくれて有難う',
#  '@ _ 11皆注目',
#  '@ふに箱',
#  '@ふに箱2',
#  '@ふに箱3',
#  '@ _ 11皆注目',
#  '@ _ 12独占欲好き',
#  '@ _ 13また傷つけちゃったな…。',
#  '@ _ 12独占欲好き',
#  '@ _ 13また傷つけちゃったな…。',
#  '@ _ 14押さない理由がわかったよ。',
#  'みんな@スクールなんかな?静か',
#  '@部活だったよ',
#  '部活おつかれ!?',
#  'ㅤㅤキワ? ㅤㅤ',
#  "@ _dyqa qy 'キ'ュウ'ワ'イキワ。",
#  'ㅤㅤ変わッてるな。ㅤㅤ',
#  '@ ama_lancer4天、速い、今は小さい',
#  '@ natsume_girugam別の我、色んな特技がある、たまにメイヴ',
#  '@ selena_ciel0920長い付き合い、優しい、たまに忙しそう',
#  '是非繋がりましょう',
#  '@/o8o2cmという所から失礼します',
#  'はい!',
#  'そんな事全然ねえから.',
#  '@ /なら滅茶苦茶絡むワ、',
#  '絡んで来んの待ってるから.',
#  'アットマークで名前出るやつ',
#  '@出せば見れると思う!',
#  'こんな感じ?',
#  'はホモじゃないはホモじゃないはホモじゃないはホモじゃないはホモじゃないはホ…',
#  '@ g_o_d__さん巻き込んでますよ!!',
#  'いやほんと小文字なのに識別されてないっていうまぁ作っただけの垢みたいだし別にいいけど',
#  '@温度と湿度、人口密度、地方民の上京、お金が消えるスピード、そして列最後尾。下北沢barrack block cafeで概念としての夏コミが開催されていました。',
#  "@ 3776のレイヤーもいたし。あと足りないものは、らら執筆のo'chawanzはかせ総受け本くらいだろう。",
#  '@バチカより厳しい、sound studio dom屋上の小屋で行われたネクロ魔1stワンマンを彷彿とさせられる人口密度だった。あとami×みずほという内容の同人、誰か描いて欲しい。',
#  '@ the !こじりンちゃンって感じがすル!あんまり絡んだことないよネ!?もう気になりすぎテハラハラしてまス!ほんとにこの機会にからみタい!これからもこじりンちゃンとからンでるとこロたくさン見せてくださイ!だいすキです!! ♡',
#  '@みルの中身さンと推してる人が一緒っていう奇跡が舞い降りましたね!ほンとにあの時は嬉しかった♡♡みルが興奮しすぎて困らせちゃってごめんね?これから気をつけまス!藁これからもどうかみルのうるささに構ってくださいだイすキです。',
#  '@ねぇ、絡んだことあンまりないよね?絡みたいよ!絡もうよ!絡も! ♡めっちゃ可愛いオーラが出てて羨ましい限りです... ♡とにかく!のように可愛いです!絡んだことがないから絡みたいって思…',
#  'idください!!!!!♡',
#  '@ love_nkun @ colon56nです。!♡蒼井くんのidも教えてくださ。!!♡',
#  '@ shouta0811aoiですoo︎',
#  '39位ありがと',
#  '@おはつい芸人やめちゃったんや',
#  'うん笑笑笑おもんないからね笑笑笑',
#  '@ _ 61ギグです',
#  '@ _ 62誰かな?',
#  '@ _ 63ややこしくなってきた?!',
#  '今更ながら金沢まとめ@金沢駅-金沢城道中@黒門前緑地=旧高峰家@玉泉庵,金沢城@兼六園',
#  '@主計町@浅野川大橋,主計町@梅ノ橋,主計町@深夜の金沢駅前-もてなしドーム',
#  '番外編@金沢城,日本の城とは思えないほど精密な石垣@兼六園かやくうどんとんかつ御膳+α',
#  '@ _ 63ややこしくなってきた?!',
#  '@ _ 64 ...。',
#  '@ _ 65可愛いこと言うね()',
#  'かしこまりました!ぜひよろしくお願いします︎︎',
#  '@ __hからはじまるアカウントからフォロー失礼します',
#  'ありがとうございます!',
#  '通知をオンにしたはずなのに引用リツイートされたものの通知が来てなくて……もしかして私だけ………ビスコ強いwwwww',
#  '@ツイートのみのタブにすると無くなるけど、全てのタブにはある…。通知の不具合かな…',
#  '設定こうなってるんだけどなぁ………通常の通知は来るんだけど、引用リツイートの通知だけのこない……なにか大切なこともあるかも!だから通知仕事してくれー!!',
#  '@うるき_ぱーぷる_ろくきゅーどうだ!!合ってるでしょ!!',
#  '@ふぇにふぇに_るるたむ私はこう読んだ!!!',
#  '@ころんくん_ごーにーろく自信ありありだよ',
#  '@ tos仕様書',
#  '@ tos艦蒐集非公式r18垢キャラ崩壊有浮上率は高め隠れ弩助平ふたなり責受両可行為時ロル中長会話時はロル無し以下好き嫌い↓',
#  '@ tos好きふたなりシーメール諸語汚喘ぎセクハラエロ誘惑催促',
#  '@ tos艦蒐集非公式r18垢キャラ崩壊有浮上率は高め隠れ弩助平ふたなり責受両可行為時ロル中長会話時はロル無し以下好き嫌い↓',
#  '@ tos好きふたなりシーメール諸語汚喘ぎセクハラエロ誘惑催促',
#  '@ tos縁繋あまり大人数と繋がっている方は気後れしますのでごめんなさい受け責め両可ですがバランスよくいきたいです縁切は合わない方b→b…',
#  'さんのafネメシスについての見解、あんまり触ったことない俺が読んでて使ってみたくなるくらいには面白かった。是非。',
#  '@とkの間空けないと俺へのリプみたいになるやろ',
#  '@ kuma10_svこうするん?',
#  '?',
#  '@のあとがw',
#  '確かにそれあるwww自分のも@のあとはばばろあきゅんに命名された笑笑',
#  'スパ崎ありがとねww',
#  '@←これつけ忘れたヾノ≧∀≦)イエイエ!今日はベルの村でアーマーするの?',
#  'つけ忘れwwwんん、大学早めに終わったらいこうかな',
#  '鍵かけ、id変更で逃亡もしくはよしよしタイムかな@ mxykivvv',
#  '@ mxykivvvvqnnそんなにid変えられてどうしたのでしょうね',
#  'おや、まだ声が届くから鍵かけたのかな。しかしフォロワーもガンガン減っていますね。',
#  '@ kiso_ama_r18『蹴りばっかですみませんです…』だそうですよ',
#  '@ samo1023『喘ぎ声エロいしすぐイくしヤっててたのしい。部屋長く開けててごめんなさい』との事です',
#  '@ janjan__sex『ころりころりとよく変わるので戸惑うこともありますが、ロル好きですよ、また、ヤりましょーね』と',
#  'は?',
#  '@ゆーま歯?',
#  'るろ剣コラボ',
#  'リプ垢作ったからいいユーザー名考えて',
#  '@ mone_no_gyouza',
#  '餃子はあかんwww',
#  '@みつちゃんいつも仲良くしてくれてありがとうすきです新しいギルドはどうかな?うちはaとsをさ迷ってますいつかえてぃあのライブ一緒に行きたいね',
#  '@ぽむち一発描きできる強いお姉さん、この間は会ってくれてありがとう私もペンラたくさん持ちたいのでお手手交換して下さい関東勢の相互さんで遊ぼうね',
#  'でた1発描きwwwわたしもいっぱい持ちたいから右手だけ交換しようか笑遊ぼ!そしてまた会おう',
#  '@ 9',
#  '@ 8',
#  '@ 7 ff外も歓迎なのです',
#  '大量の風鈴が@美浜',
#  '@若狭本郷',
#  '東舞鶴到着@東舞鶴',
#  '@れむちみちのく湖畔公園花粉症にはつらい季節に行って鼻水ズルズルでしんどい思いしたい',
#  '@めるち光のページェント寒いリア充多いって騒いで暖かいココアのみたい',
#  '@こた天文台あっちょっと寝てた…ってなりたいプラネタリウム見たあと寄ったかも…ってグダグダしたい',
#  '2.シナモンちなシナモンの公式twitterコチラ↓',
#  '@小豆ちゃんめっちゃすこです。パオパオチャンネルいい感でぃなので絶対見てください。',
#  '4.轟ちゃんすんごい好きです。いつも動画楽しみにしてるんです絶対見て!!',
#  '私も前何回も報告して本人にリプ送ったりしたんですけど今検索したらなぜか引っかからなかったです…id教えてもらっていいですか?',
#  '@ satsu0gintamaこれです!私もdmで注意したんですけど返事来なかったです…たぶん自動でツイートされるようにしてるんだと思います!',
#  'ありがとうございます!今チェックしたらこんな風に銀魂オタクと名乗るならほぼ絶対間違えるはずのないミスをしてたので多分もう長い間放置して自動ツイートなんだと思います…多分何しても反応しないのでみんなで報…',
#  'はい、鍵垢同士でお願いしたいです',
#  '@/achan315921へフォロリクお願いします',
#  '@ 6からはじまるアカウントでフォロリクしました',
#  'リプありがとうございます!アカウント教えて頂ければフォロリク送らせて頂きますので宜しくお願い致します!',
#  '@ fate__raccoonまでフォロリクお願いします*_ _)',
#  'ありがとうございます⋆⸜フォロリク送らせて頂きますのでお手隙の際に承認して頂ければ幸いです。宜しくお願い致します',
#  'he vuelto de mi primer día de trabajo y me he puesto la playlist del westival porque creía que era buena idea.',
#  '@ jwest si voy a aguantar estos 3 meses ahíes por vuestra culpa, ya podéis hacer que merezca la pena',
#  'acaba de saltar何万回だって「君が好き」y me he empezado a reír de los nervios y a decir estoy hasta el coño de esta canción. y…',
#  '@れいんステあがった???れいんといったらりおのリプ欄にめっちゃいるイメージだ!ww',
#  '@ももたこももたこかわいいいいいいいいああああああああまた配信してほしい!彼氏さんとおしあわせにだよ',
#  '@うめこんぶクソリプまだか?¶⁋wwwわたしが男だったらうめこんくんみたいな人になりたかった️囲いをわけて',
#  'ホーム画面',
#  '@打って出てきた人3名様',
#  'え、みんな大好きでいいかな??一人一人じゃないもんね!',
#  '@ 16僕悪いスライムじゃないよ.怖がらないで僕を知って?',
#  '@ 16名前€スイ年齢€人間にして15歳性別€オス種族€スライムと人間のハーフスライム族から憎まれる人型として生まれた為,里から追い出された少年.迷いの森に暮らしている.警戒心が強く,慣れると人懐こい.身体を軟体と…',
#  '@ 16 like:溺愛.甘々.多ハグ.多キス.展開重視.長文.シリアス.モブ.アブノ全般.多ラウンド.アヘオホ.♡乱舞.寝取り.淫語.諸ロルetc ng:グロ.死.暴力.ワンナイト.即槍.背後詮索.面倒事.短ロル.縁繋…',
#  'nabe__pad',
#  '@つけ忘れてるぞ',
#  'チキって付けないでおいたwww',
#  'まって、それ本当の歌詞かと思ったじゃんwwwwwwwとりあえずねろぴょんもるなちゃんに謝って',
#  '@ちゅーず_るーごめんなさい大人やからちゃんと謝っといたで←',
#  'めちゃくちゃワロテルwww',
#  '@ 6!',
#  '@ 5!',
#  "|ω' )ヌッ",
#  'なりすましめんどくさい、いちいちみんなになりすましだからねってリプ送らんとだし相当暇人でしょ、。注目浴びたいならちゃんと自分としてアカウントつくりなよ。こんなやり方ださいし負け犬みたいで笑うよ。おつかれさまみんなこいつ…',
#  '@もほとんど同じにしててワロタwwwwww',
#  'それwww 36になってて草',
#  'これは…笑私わからんのにはいってるの?笑',
#  '@押して出てきた順にフォロワーさん載せたから…わからんって言っても自分の推し紹介やねんからいいやん笑強制じゃないからやらんでいいで',
#  '私こっちの垢仲良しさん少ないからなぁwwwまた今度w向こうの垢やったら出来るしやりたみンフ',
#  'それもう凧って漢字の方がよっぽど優秀じゃない?',
#  '@凧',
#  'at凧ってつまりこういうことですね。そしてこの一連のくだりから学ぶべきことはいらすとやの優秀さです。',
#  '@ syn0_アイコンはあんまんらしいが、実は期間限定の極上にくまんだった',
#  '@ meitetu2002名古屋鉄道のファンなのは自分が名古屋住みだからというのも理由の1つらしい',
#  '@ water_fish_jp電脳世界に入り、エンガードを存分にいろいろしてきたことがあるらしい',
#  '普通に紛れ込んでるじんくんwwww',
#  '@つけてないからほんっとに普通のフォロワーさんみたいでなんかおもろいwwww',
#  '@つけてないのにいいね嬉しいよね',
#  'じゃぁ@つけて',
#  '@か…かすみんありがとう',
#  'いやいやwww',
#  '@:/-待ち草臥れ荘何嶽度',
#  '@:/-名乗り出て',
#  '@:/-俺の御前とでも言って於くか',
#  '今日城ホで現地販売するグッズをまとめておきます→',
#  '@ rak_lisa様フォトポストカード',
#  '@ paintitblack_jn様スローガン2500円12時30半から販売予定',
#  '@ nima09choco25コッショリ',
#  '@ potter17698581結構まめに反応をくれるから嬉しかったりする。貴重な.hack//勢',
#  '@ aeehvuyuc9qst9o @ h_sandora最近繋がったばかりであまり絡めてないので私の自己紹介しますね!!!!こんにちは!臣です!ショーン推してます!ネタ部屋に生息する推理できないマンです!ネタ部屋ではショ…',
#  '@ potter17698581結構まめに反応をくれるから嬉しかったりする。貴重な.hack//勢',
#  '@ aeehvuyuc9qst9o @ h_sandora最近繋がったばかりであまり絡めてないので私の自己紹介しますね!!!!こんにちは!臣です!ショーン推してます!ネタ部屋に生息する推理できないマンです!ネタ部屋ではショ…',
#  '@ ray_rei_ray_rei',
#  '@ aeehvuyuc9qst9o @ h_sandora最近繋がったばかりであまり絡めてないので私の自己紹介しますね!!!!こんにちは!臣です!ショーン推してます!ネタ部屋に生息する推理できないマンです!ネタ部屋ではショ…',
#  '@ ray_rei_ray_rei',
#  '@ flowerskalmiaだいふく部屋での観戦仲間入室が素早いお嬢様的雰囲気を纏い、姉の様な包容力を持つとても優しい無理に夜更かしすると体調を崩してしまうらしい',
#  '次は龍ヶ崎市です。the next station is ryugasakicity',
#  '@龍ヶ崎市駅???「この電車は竜ヶ崎駅行きです」鉄オタ「似たような駅名にすんなよ」地元民「」地元民以外「?????????」',
#  '<ンンンンンンンンンンンンンンwww( ^…',
#  'ねぇ、lineの便乗の指名のやり方忘れたwww',
#  '@つければすぐ',
#  '美優とかが出てこないwww謎やね、うん、w',
#  '@関東軍',
#  '@十字軍',
#  '@アサシン教団',
#  'iphoneだとないので、エントリー等の管理で使いたいなら@ line使っても良いと思います。',
#  '@って全くお金かからないんでしたっけ?',
#  '1:1トークのみの利用なら無料で使えたはずですよ。それが面倒臭いなら別の機種を用意してエントリー用とかで使うとかですかね。',
#  '一人でボソッとあざす。って呟いてしまった。',
#  '@磐梯町東長原',
#  'マイクロさんほんとありがとう。フルーティア最高。と叫びたいとこですが、フルーティアのモーターのやる気がなさすぎて、一般車側のモーターが常にフルーティアを押して歩いてる感じです。',
#  'コピペすると入れれないから@も含めて全部手打ちですると出来るよ、たぶん',
#  '@忘れてたああぁぁwww',
#  '@ rui__まで反映されてるwwwアンダーバー2つよ',
#  'わかる',
#  '@有害じゃないって部分くっっっっそ腹立つんだけどwwwwww',
#  'わかるwwwむりくそはらたつwwwついーともきらい',
#  '何書く?www',
#  '@マークつけてだれだれとペア画ー!!ってw',
#  '書いても書かなくてもどっちでもいいよんwww',
#  '見方がわかんなぃよー。サインのひと?',
#  '@の自分番号と最初にツイートした番号が対になってるからそれでなんの人かわかるみたい。なんの人かってのはどーやって決まってるのか謎。',
#  'なんであっきーがサインの人なのかwww',
#  'アイコン一緒だと本当に見分けつかねぇ…!!!',
#  '@のさきと、へっだーもかえようかとおもったけどガチでわからなくなるからやめた',
#  'そこまでしたら本当に分からなくなる',
#  'クロック回路にキルコマンド繋げて詰みました()',
#  '@ a?',
#  '@ p type=!kirisame1226になってるから霧雨ちゃん以外止めれなくなったwwwwwwww',
#  '続いてラクレット料理都内どこを探してもうちの店より安い店は見たことがない大体の相場だと2500がざらだけどうちの店見てみて1000円前後しかもしっかり目の前でかけさせてもらいます!仕入れによりその場でかけれない日もありますが',
#  '@パークハイアット新宿@ラクレット@サバゲ@ミリタリー@サバゲ好きと絡みたい@拡散希望希望@ドンナドーロ新宿',
#  'おはようございます!8月から僕の名刺に10%offって書いてる名刺のみディナーのみ会計時にから10%offになります。また連れてきたお客がまた来店した際はなんと20%offさらに10名以上のパーティーならば1品サービスこちらは…',
#  'さくらくんとは…!!!!',
#  '@ sakura_25nico、!!!!',
#  'ごめんごめんごめんごめんごめん',
#  'そのうち、どうにかなるさ。',
#  '@マイカタ',
#  '風鈴持って来て、take 2!',
#  '好きなそー!',
#  '@まつもとももな',
#  'アルティメット好きなそ、、、',
#  '@ _ 34みゅくん',
#  '@ _ 35グギの逆のギグは?',
#  '@ _ 36ちょーだい',
#  '@ _ 39愛してる',
#  '@ _ 40今度は直接言ってよ',
#  '@ _ 41嫌な事あったら報告して。',
#  'お返事とツイフィールの一読ありがとうございますどちらのアカウントをフォローさせていただいたら宜しいでしょうか?',
#  '@ __knhr99こちらのアカウントをフォローして頂けると助かりますお手数おかけします',
#  '@ yyから始まるアカウントからフォローさせていただきました!宜しくお願いします',
#  'それはお土産なのかな',
#  '@つけ忘れたのによくわかったな',
#  'ツイ廃なんだよね',
#  'よき!声がやばい!歌詞がやばい!だいすき!',
#  '@',
#  'それぐらい知っとる',
#  '@`04',
#  '@`05',
#  '@`06おやすみとか言わず起きてよ',
#  'ねぇwwwwwwwわらいとまらんwアットマークつけずにうけるwwwwほんとに、山口さんってwwつっこんだよね笑',
#  '@つけたはずなんだけどwwwwwwww山口県出身の山口さんあやうくアナウンスがなければそのまま山口さんだったかもしれんねwwww',
#  'つけたの!?wwwもう爆笑おさまらんかったあのときwつぎのひもやまぐちさんだったからこっそり、修正テープでけして山本に書き換えたwwwwwww',
#  'なう',
#  '@じゃん!!我が家!!!可愛いメイドさんたくさんいるけど、まぬんちゃんの方がかわいいな!',
#  'すごいwwwよく分かったねwwwみらくるおすすめのメイドさん聞いてから行けばよかたかも',
#  'せーのでティアラなるか笑',
#  '@ちくわ→@ティアラ魔剤?!',
#  '別にちくわのオタクじゃないんだけどwww',
#  'ひとまずヤーバメヤン貼っときました',
#  '@ひこさんの奥さんあと、ひこさんの奥さん召喚しときました',
#  'きっと見ても、ふーん、そーで終わります',
#  'ぜひ!お願いします!!',
#  '@ miから始まるアカウントからフォローさせてもらいました!よろしくお願いします♡♡',
#  'ありがとうございます!フォロバしました\\/',
#  'るらさん、私です♡るらさんと話したかったです',
#  '@で話しかけるのはできるみたい?アカウント見に行くといませんってなっていて、フォロー画面からフォローしようとするとブロックされていますって出て来てフォロー出来ない',
#  'ブロック!してねーノ',
#  '旦那が寝とるけど今日とてつもなく動くし寝にくいのかなんなのか。って打ちよったら起きたわwwww @あー可愛い',
#  '@要らんやん。',
#  '笑かすなwww',
#  'xukun big screen video support on tropicana avenue in las vegas! the video will be shown 1440 times a day and will…',
#  '@/ stylish_kun visited kids w disabilities and donated a bunch of art supplies which they used to make birthday car…',
#  'a shanghai expo and led for xukun by @/ @怡宝小迷糊ikun',
#  'いないのでぜひ繋がりたいです੭⁾⁾',
#  '@ so8pigこちらのアカウントまでフォロリクお願いします',
#  '@ upからはじまるアカウントからリクさせていただきますoo︎♬︎',
#  'さかえさん、はじめまして!通知16件はビビリますね',
#  '@まつさか様なんだろうって思いましたw',
#  'ですよねーwww',
#  "@ ' n o . 2 _特別扱い_俺は特別扱いされると喜びます。俺だけのリストとか作ってくれたら凄い嬉しいかなッㅋㅋ",
#  "@ ' n o . 3 _嫉妬_勿論自分も気に入った相手が出来たら嫉妬しまくりです…色々質問攻めしちゃうけどちゃんと答えてくれたらいいななんてㅋ",
#  "@ ' n o . 4 _性格_俺の性格は口悪甘えたさんかな。甘えてる時は寂しい時、口悪い時は嫌なことがあった時。って思ってもらえればいいかな…",
#  "@ ' n o . 3 _嫉妬_勿論自分も気に入った相手が出来たら嫉妬しまくりです…色々質問攻めしちゃうけどちゃんと答えてくれたらいいななんてㅋ",
#  "@ ' n o . 4 _性格_俺の性格は口悪甘えたさんかな。甘えてる時は寂しい時、口悪い時は嫌なことがあった時。って思ってもらえればいいかな…",
#  "@ ' n o . 5 _ツイート_よく喘ぎのツイートしちゃってます…が!無視してください…。ただムラつかせたい人が居るからツイートしてます。はい。あと惚気とかもねツイートしちゃうかも知れませんが宜しくです←?",
#  "@ ' n o . 4 _性格_俺の性格は口悪甘えたさんかな。甘えてる時は寂しい時、口悪い時は嫌なことがあった時。って思ってもらえればいいかな…",
#  "@ ' n o . 5 _ツイート_よく喘ぎのツイートしちゃってます…が!無視してください…。ただムラつかせたい人が居るからツイートしてます。はい。あと惚気とかもねツイートしちゃうかも知れませんが宜しくです←?",
#  "@ ' n o . 6 _テンション_辛い事がない限りいつも元気です。元気100倍ジミンパンマンなんですㅋㅋ皆ちゃんとついてきてね?",
#  '@ /お友達探し用あかうんと。仕様書等は只今作成中。要点だけ纏めておきます。大丈夫そうなまだ見ぬ貴方様へ、繋がって下されば其れは僥倖の身。当方は、刀i剣乱l舞の髭l切さンとの恋路を歩むあかうんと。各一思考故見定め陳謝。…',
#  '@ /独白が多め、凍結垢にて呟く。其方様本丸との区別は着いているので、髭l切さンのお話をしても構いません。自本丸≠他本丸思考です。精神や体調、持病等の問題によりアルバイトはしてない身。故に課金やグッツ等はあま…',
#  '@ /以上仕様書でした。上記が駄目だな、受け付けられないな。そう思った方は回れ右を。ㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤ',
#  'みたらしし@てゆたんぽぽ@ゃん',
#  '@て',
#  '@足',
#  '@て',
#  '@足',
#  '手足はやばい',
#  '東京も京都も最高気温が20℃くらい………よくわからない。コートもマフラーもいらないんですか教えてエロい人',
#  '@エロい人',
#  'www寒いのか暖かいのかよくわからないので、何を着れば良いのか謎ですw',
#  'オキナワンハロウィン',
#  '@北谷美浜アメリカンビレッジ',
#  'この人死ぬほどイケメンだった',
#  'そ、そうですね',
#  '@行った時に聞いてみて',
#  '自分で見せてこれ欲しい?はめちゃくちゃ恥ずかしいですよwww口から火出ますよ',
#  '@卒業式の集合写真の欠席者みたいなやつがクソだせえと思ったけど冒頭だけで良かった。',
#  '@だけじゃねえ!',
#  '@あああれだ、コマの外から出て登場人物にツッコミを入れてくる作者的表現だな',
#  '何これかわいい',
#  '@ toukadou_sumi ←',
#  '左',
#  '@ _ 68どのくらいがいいか?',
#  '@ _ 69甘えたい…、',
#  '@ _ 70そうだよ',
#  '@座間総合@湘南台@新城@逗子@茅ヶ崎@上矢部',
#  '@元石川@荏田@大和西@横浜桜陽@横浜清陵',
#  '@カリタス@高津@向上@相模女子@清泉女学院@洗足学園@橘学苑',
#  'お返事遅れてしまい申し訳ないです...わたしでよければ是非よろしくお願いします♡お手数ですが@ _onlybooまでフォロリクお願いします️',
#  '@ nから始まるアカウントからフォローさせていただきました︎',
#  'ありがとうございますよろしくお願いします!',
#  '@最近浮上してないねあんまり寂しいよーって笑早くみんなで会いたいね! @これ言ったらわかるかぬʬʬʬもーねめっちゃ面白いʬʬ早く通話したいしʬʬʬしんどʬʬʬ@おぉ通話楽しかったね笑最初緊張しまくりで喋んなくてごめんʬʬʬ良かったらまたしよʬʬ',
#  '@はい来ましたよしっʬʬʬ今日キャス楽しかったねーʬまた行くわもーそっちに住みたい早く会いたいし@おぉ一言○○の加工画大好きよ♡♡@はい出ました変態line返信遅いしもうおこだぞʬʬʬ○○不足でわないけど絡んでくださーい',
#  '@あ、安定だ笑出てくると思わんかった笑えっとですねあなたへの愛はlineのtlで語ってるので良かったら見てくださいʬʬʬ@お、こちらも下が紫の愛方ちゃんではないですか笑笑吹奏楽のやつおつかれ!もっともっと濃く絡みに…',
#  '新しいアイコンはゆにさんに描いて頂きました…!!可愛すぎてアイコンじゃ自分の垢に見えない…',
#  '@←仕事してないですєэ',
#  '@つけちゃうと通知行っちゃうのであえてですw',
#  'お返事ありがとうございますどちらの垢にお迎えに行けばよろしいでしょうか?oo♡♡',
#  '@/xuiso_が本垢になるのでフォロリクいただけるとうれしいです꒰ᐢ⸝⸝•༝•⸝⸝ᐢ꒱',
#  '了解致しましたo♡♡',
#  '@愛しさと刹那さと心強',
#  '@さ',
#  '@と',
#  '@さ',
#  '@と',
#  '@万事屋銀ちゃん',
#  'みてみる',
#  '@ kazegusuri2こいつかねぇ?',
#  '@ kazegusuri2 @ kh314kudoやな',
#  'キャリーあざます',
#  '@違うくてくさ',
#  'なんで変わってんだよwww',
#  'どうも、アゴシンです!!今回は、「顎で化石掘り出してみた。」やっていきたいと、思いまーす!!!',
#  '@アゴシンtvさんアゴシンって何が面白いんですか?顎がコンプレックスの人もいるんですよ?謝ってください。せっかく好きだったのにチャンネル登録も高評価も全て外させてもらいました、改善してくれることを待っています。',
#  '@菜さん配慮が足りず申し訳ありませんでした。次の動画にて経緯を説明させていただきますので見ていただけると嬉しいです。',
#  'ねね、最近おまるのリプ、何個かに1個表示されなかったり通知来ないwwwwwwww',
#  '@の方の通知のが、まだましよねまるも通知あかん時ある⁝⁝wwwwww',
#  'なんか、会話のながれでも、おまるのつぶやきだけこのツイートは表示できませんって非表示?になるときあるよwww',
#  'ふぇ?!なにを?www',
#  '@の後ろ!!',
#  'あねキャハ♪"は',
#  '嬉しいお言葉ありがとうございますそれでは当方からお迎えにあがりますのでアカウントの方をお聞きしても宜しいでしょうか。',
#  '@ x_0422_xになります♪よろしくお願いします₍ᐢ. ̫.ᐢ₎',
#  '当方フォローリクエスト送らせて頂きました@ maから始まるアカウントです。ご確認の方よろしくお願いします。',
#  '@/열우왕아주기쁜말감사합니다ㅠㅠ저도친해지고싶어요ㅠㅠ혹시제트친소에흔적남겨주셨나요? 제가아직많은분들께만나러가지못해서너무죄송해요ㅠㅠ꼭만나러갈거니까조금만기다…',
#  '@/열하나그죠!! ㅜㅜ나도그래요ㅜㅜ제가추천하는반법은일상생활안에서나앱을사용해서일본어를쓰는반법이에요! 저도앱쓰고나이렇게직접한국분이랑소통을해서배운것도많으니까요!',
#  "@/열두今晩は!凄く日本語上手です!!こちらこそ宜しくお願いします︎( 그리고처음뵙겠습니다는'始めまして' 가아니라'初めまして' 에요!「始め」는「시작」을의미하는…",
#  '強いかよwww',
#  '@つよいwwこっちも、えっ?あ、え?魔風??ってなってたよw',
#  'こたぬきつけてるの3垢だけねwwwあの垢は割と過激発言してないからねwww',
#  '窓付き@のノンファンタジー聞こうbotしていいか???',
#  '@ tosでどうぞ',
#  '表示するなとwww',
#  'いいなーてかその()れはも付けてたなに',
#  '@ zxr288rrこいつのまね',
#  'あーwwwてかなんで鍵',
#  '知ってるるる',
#  '@ñp',
#  'え、こわ。',
#  '尊敬してるし、私とお話してくれて、構ってくれて感謝しかない。すきだよー!! @人外ロルマン。私とは同村あんまりしてくれない...根に持ちますよ!?...て、冗談も受け入れてくれそうな人。語彙力凄いくせに謙遜ばっかしていい人が透けてます。仲良くしてくれてありがとうございます!',
#  '@語彙力と対応力の神。リストで遊ぶっていうおちゃめな1面もある。勝手に尊敬してます。いつも私が力不足で大胆なロルをしてしまうのを居る時は助けてくれる。すきです@いつもわちゃってくれる。3人で戯れるの好きだしたまに予想外…',
#  '今度また私を攫ってほしい。イチャイチャしよ????大好きです。@最近高校生ってわかって驚いた。あれだけの語彙力と閃を持っていてよくsロルしてる。私はあのsロル大好きです。怖いけどあとは私を語彙力あるとか言ってる。ないです。1度此方と村で純粋に付き合ってみたい。',
#  'え??!?インスタライブしたん?行きたかった!!!',
#  '@ __.rengramの方で30分した!彼氏の話しかしてないよww',
#  '声聞きたかった…次やる時教えてね!!',
#  '@各位',
#  '@各位',
#  '@各位',
#  'ヘッダーは?',
#  '@っのやつでお願いします',
#  'お待たせしました!',
#  '貴重な1人目貰ッた、寂シさ埋めてあげるから於いで?空くン',
#  '@くん優しいね。そしてホーム拝見させてもらったけど、ど変態なお兄さんだね?',
#  '可愛、可愛空くン。ド変態は、まァ認める笑変態兄さン嫌い?',
#  '通話誘え下さい',
#  '@の後ろがなければ誰かわからなかったわ',
#  'これ便利www',
#  '@＂no . 2可愛い俺の兄さん',
#  '@＂no . 3地震大丈夫か?停電しとるん?',
#  '@＂no . 4俺のポケモンカビゴンちゃん俺が育てる',
#  'ん?ちょっと理解できないっ',
#  '@泉の広場',
#  'わろたwww',
#  'りょ!',
#  '@ mt49496ぺんか!',
#  '@ ringo_apple01りんご',
#  '明日6日21時エンジョイプラベ┓',
#  '@ 3ありますお気軽にどうぞ',
#  '@ 2あります',
#  'すこぶるって入れて欲しい?それともユーザネーム?',
#  '@すこぶる動くとまとって入れてほしいです!',
#  'どーぞ!',
#  '@//:何でもどうぞ。',
#  '@ //: 01おめでとう、お題箱1人目。',
#  '@ //: 02お題箱というよりもホソク箱だね。この流れを寸断するのは誰だろう',
#  'ぽぬくん無事そうでよかった!大変なところ恐縮ですが、しばちゃの垢もしくは安否知ってたりしますか?',
#  '@ pepwnsで出ると思う!しばちゃ無事です!',
#  'あっ空白入れてる事忘れてた&gt;&lt; @の後ろの空白はいらないです!',
#  'デュエルしようぜ',
#  '@',
#  'ポケモンマスターに俺はなる!!',
#  '陸部マネだったの!サッカー部マネかと思っとった!',
#  '@のあとranって打ってるつもりがrunって打ってた',
#  'ありがとうございます走りますwww',
#  '今日は定時で仕事終わりにして帰ってきた!ただいまー!',
#  '@・ェ・@おかえりなさいませご主人様!ご飯になさいますか?お風呂が先ですか?それとも、た・わ・し?',
#  'た・わ・しwww',
#  '明日は石田しょうやが「いいから」歌うらしいです!ききにきてくださーい',
#  '@な、いしだ!!',
#  '場所は3年3組の教室ですす\u200d️自分でゆうたからしっかり歌ってもらわないとたのむでいしだ',
#  '暇だからやるひとことも書く',
#  '@ゆーま←何か出てこなかったwいいねありがとうございます!字汚いのは許して、、',
#  '@もえいいねありがとうございます!',
#  'しかしそれは、epdで後発★14を突き放すと云う前提の話。その場合だけ8sで仕立ててないと厳しくなってて、その8s因子素材仕立てるだけで、もうそろそろ1年失敗続けてますがね・・・',
#  '@最新★14のようにsop付かないので、素材準備難易度が桁違い・・・',
#  'ぬーん....先は長いですなぁ...自分中ではこれが1番っていう...']

# %%
import MeCab

# %%
mecab = MeCab.Tagger()

# %%
mecab.parse("うんこが大好き").split("\n")
sentence = "あぁうんこが大好き"
for m in mecab.parse(sentence).split("\n"): # 形態素解析で単語に分解する
    print(m)
    w = m.split("\t")[0].lower() # 単語
    print(w)
# Out:
# あぁ	感動詞,*,*,*,*,*,あぁ,アァ,アー
# あぁ
# うんこ	名詞,一般,*,*,*,*,うんこ,ウンコ,ウンコ
# うんこ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# が
# 大好き	名詞,形容動詞語幹,*,*,*,*,大好き,ダイスキ,ダイスキ
# 大好き
# EOS
# eos

# %%
a = 'aaa'#'ﾍﾟｺﾘ'
print(a)
a.upper()
# Out:
# aaa
# 'AAA'

# %%
a = 'ああああぁぁぁうんこが大好きだし、ももも好きwwｗｗWWＷＷ'.lower()#'おいし〜〜〜〜い'
print(a)
a = re.sub(r'あ{3,}','あ',a)
a = re.sub(r'ぁ{2,}','ぁ',a)
a = re.sub(r'w{2,}','',a)
print(a)
a = neologdn.normalize(a,repeat=2)
#print(a)
# Out:
# ああああぁぁぁうんこが大好きだし、ももも好きwwｗｗwwｗｗ
# あぁうんこが大好きだし、ももも好きｗｗｗｗ

# %%
twitter_data[0][27].encode('utf-8')
# Out:
# b'\xe3\x81\x8a'

# %%
tweet_text = 'ぃぃぃぃあいうえおいいいいい'
re.sub(r'ぃ{2,}', 'ぃ', tweet_text)
# Out:
# 'ぃあいうえおいいいいい'
